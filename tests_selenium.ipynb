# %%
import requests as req
import json
import cloudscraper as csp # using cloudscraper to bypass cloudflare bot protection, works like requests
from bs4 import BeautifulSoup # for scraping

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/115.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9",
    "Accept-Language": "fr-FR,fr;q=0.9,en;q=0.8",
    "Referer": "https://www.google.com",
}


url="https://touch.dofusbook.net/stuffs/touch/public/?page=1&user=248432-db&sort=update-desc"

# scraper = csp.create_scraper()  
# resp_csp=scraper.get(url) 

resp_head=req.get(url,headers=headers)
resp=req.get(url)
resp.content
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->\n<head>\n<title>Attention Required! | Cloudflare</title>\n<meta charset="UTF-8" />\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n<meta name="robots" content="noindex, nofollow" />\n<meta name="viewport" content="width=device-width,initial-scale=1" />\n<link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />\n<!--[if lt IE 9]><link rel="stylesheet" id=\'cf_styles-ie-css\' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->\n<style>body{margin:0;padding:0}</style>\n\n\n<!--[if gte IE 10]><!-->\n<script>\n  if (!navigator.cookieEnabled) {\n    window.addEventList
# ...

# %%
print(resp.headers)
# Out:
# {'Date': 'Thu, 11 Sep 2025 13:39:16 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Cache-Control': 'private, max-age=0, no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Expires': 'Thu, 01 Jan 1970 00:00:01 GMT', 'Referrer-Policy': 'same-origin', 'X-Frame-Options': 'SAMEORIGIN', 'Vary': 'accept-encoding', 'Report-To': '{"group":"cf-nel","max_age":604800,"endpoints":[{"url":"https://a.nel.cloudflare.com/report/v4?s=tj5jfiP8IbkoiFXD7iUI05ilacPeGeYVMXmvyrCDtz1ChEnRD1OXiDoxdiKzIubdhekdqRA%2B48wA%2BcGTZrMGU%2FT8jLK2oysximdATLjEwSYYT7ivhBZV2FwocjZR6g%3D%3D"}]}', 'Nel': '{"report_to":"cf-nel","success_fraction":0.0,"max_age":604800}', 'Content-Encoding': 'gzip', 'Server': 'cloudflare', 'CF-RAY': '97d791fbeef76fa5-CDG', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
print(resp_head.headers)
# Out:
# {'Date': 'Thu, 11 Sep 2025 13:39:16 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Cache-Control': 'private, max-age=0, no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Expires': 'Thu, 01 Jan 1970 00:00:01 GMT', 'Referrer-Policy': 'same-origin', 'X-Frame-Options': 'SAMEORIGIN', 'Vary': 'accept-encoding', 'Report-To': '{"group":"cf-nel","max_age":604800,"endpoints":[{"url":"https://a.nel.cloudflare.com/report/v4?s=OnS7%2FQLkF1B6VkVcLfWrLiQjL2PB3WYbgcMBLBTm6mTKxHIrJ2w2ydOAkJxh55j%2B%2FaewvRVv%2B6yx2qY%2Fa3DbyU5Tp9wjuT0XyiY7vJIdy2iDdpHBfM%2BNQIl3IWY6Fg%3D%3D"}]}', 'Nel': '{"report_to":"cf-nel","success_fraction":0.0,"max_age":604800}', 'Content-Encoding': 'gzip', 'Server': 'cloudflare', 'CF-RAY': '97d791fb8ffc0346-CDG', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
soup=BeautifulSoup(resp.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Attention Required! | Cloudflare
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="noindex, nofollow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/cdn-cgi/styles/cf.errors.css" id="cf_styles-css" rel="stylesheet"/>
#   <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
#   <style>
#    body{margin:0;padding:0}
#   </style>
#   <!--[if gte IE 10]><!-->
#   <script>
# ...

# %%
headers_val="""X-Originally-Forwarded-For: /admin/console
X-Originally-Forwarded-For: 10.0.0.0
X-Originally-Forwarded-For: 10.0.0.1
X-Originally-Forwarded-For: 127.0.0.1
X-Originally-Forwarded-For: 127.0.0.1:443
X-Originally-Forwarded-For: 127.0.0.1:80
X-Originally-Forwarded-For: 172.16.0.0
X-Originating-: /admin/console
X-Originating-: 10.0.0.0
X-Originating-: 10.0.0.1
X-Originating-: 127.0.0.1
X-Originating-: 127.0.0.1:443
X-Originating-: 127.0.0.1:80
X-Originating-: 172.16.0.0
X-Originating-IP: /admin/console
X-Originating-IP: 10.0.0.0
X-Originating-IP: 10.0.0.1
X-Originating-IP: 127.0.0.1
X-Originating-IP: 127.0.0.1:443
X-Originating-IP: 127.0.0.1:80
X-Originating-IP: 172.16.0.0
True-Client-IP: /admin/console
True-Client-IP: 10.0.0.0
True-Client-IP: 10.0.0.1
True-Client-IP: 127.0.0.1
True-Client-IP: 127.0.0.1:443
True-Client-IP: 127.0.0.1:80
True-Client-IP: 172.16.0.0
X-WAP-Profile: /admin/console
X-WAP-Profile: 10.0.0.0
X-WAP-Profile: 10.0.0.1
X-WAP-Profile: 127.0.0.1
X-WAP-Profile: 127.0.0.1:443
X-WAP-Profile: 127.0.0.1:80
X-WAP-Profile: 172.16.0.0
From: /admin/console
From: 10.0.0.0
From: 10.0.0.1
From: 127.0.0.1
From: 127.0.0.1:443
From: 127.0.0.1:80
From: 172.16.0.0
Profile: /admin/console
Profile: 10.0.0.0
Profile: 10.0.0.1
Profile: 127.0.0.1
Profile: 127.0.0.1:443
Profile: 127.0.0.1:80
Profile: 172.16.0.0
X-Arbitrary: /admin/console
X-Arbitrary: 10.0.0.0
X-Arbitrary: 10.0.0.1
X-Arbitrary: 127.0.0.1
X-Arbitrary: 127.0.0.1:443
X-Arbitrary: 127.0.0.1:80
X-Arbitrary: 172.16.0.0
X-HTTP-DestinationURL: /admin/console
X-HTTP-DestinationURL: 10.0.0.0
X-HTTP-DestinationURL: 10.0.0.1
X-HTTP-DestinationURL: 127.0.0.1
X-HTTP-DestinationURL: 127.0.0.1:443
X-HTTP-DestinationURL: 127.0.0.1:80
X-HTTP-DestinationURL: 172.16.0.0
X-Forwarded-Proto: /admin/console
X-Forwarded-Proto: 10.0.0.0
X-Forwarded-Proto: 10.0.0.1
X-Forwarded-Proto: 127.0.0.1
X-Forwarded-Proto: 127.0.0.1:443
X-Forwarded-Proto: 127.0.0.1:80
X-Forwarded-Proto: 172.16.0.0
Destination: /admin/console
Destination: 10.0.0.0
Destination: 10.0.0.1
Destination: 127.0.0.1
Destination: 127.0.0.1:443
Destination: 127.0.0.1:80
Destination: 172.16.0.0
Proxy: /admin/console
Proxy: 10.0.0.0
Proxy: 10.0.0.1
Proxy: 127.0.0.1
Proxy: 127.0.0.1:443
Proxy: 127.0.0.1:80
Proxy: 172.16.0.0
CF-Connecting-IP: /admin/console
CF-Connecting-IP: 10.0.0.0
CF-Connecting-IP: 10.0.0.1
CF-Connecting-IP: 127.0.0.1
CF-Connecting-IP: 127.0.0.1:443
CF-Connecting-IP: 127.0.0.1:80
CF-Connecting-IP: 172.16.0.0
Referer: /admin/console
Referer: 10.0.0.0
Referer: 10.0.0.1
Referer: 127.0.0.1
Referer: 127.0.0.1:443
Referer: 127.0.0.1:80
Referer: 172.16.0.0
X-Custom-IP-Authorization: /admin/console
X-Custom-IP-Authorization: 10.0.0.0
X-Custom-IP-Authorization: 10.0.0.1
X-Custom-IP-Authorization: 127.0.0.1
X-Custom-IP-Authorization: 127.0.0.1:443
X-Custom-IP-Authorization: 127.0.0.1:80
X-Custom-IP-Authorization: 172.16.0.0
X-Custom-IP-Authorization..;/: /admin/console
X-Custom-IP-Authorization..;/: 10.0.0.0
X-Custom-IP-Authorization..;/: 10.0.0.1
X-Custom-IP-Authorization..;/: 127.0.0.1
X-Custom-IP-Authorization..;/: 127.0.0.1:443
X-Custom-IP-Authorization..;/: 127.0.0.1:80
X-Custom-IP-Authorization..;/: 172.16.0.0
X-Originating-IP: /admin/console
X-Originating-IP: 10.0.0.0
X-Originating-IP: 10.0.0.1
X-Originating-IP: 127.0.0.1
X-Originating-IP: 127.0.0.1:443
X-Originating-IP: 127.0.0.1:80
X-Originating-IP: 172.16.0.0
X-Forwarded-For: /admin/console
X-Forwarded-For: 10.0.0.0
X-Forwarded-For: 10.0.0.1
X-Forwarded-For: 127.0.0.1
X-Forwarded-For: 127.0.0.1:443
X-Forwarded-For: 127.0.0.1:80
X-Forwarded-For: 172.16.0.0
X-Remote-IP: /admin/console
X-Remote-IP: 10.0.0.0
X-Remote-IP: 10.0.0.1
X-Remote-IP: 127.0.0.1
X-Remote-IP: 127.0.0.1:443
X-Remote-IP: 127.0.0.1:80
X-Remote-IP: 172.16.0.0
X-Client-IP: /admin/console
X-Client-IP: 10.0.0.0
X-Client-IP: 10.0.0.1
X-Client-IP: 127.0.0.1
X-Client-IP: 127.0.0.1:443
X-Client-IP: 127.0.0.1:80
X-Client-IP: 172.16.0.0
X-Host: /admin/console
X-Host: 10.0.0.0
X-Host: 10.0.0.1
X-Host: 127.0.0.1
X-Host: 127.0.0.1:443
X-Host: 127.0.0.1:80
X-Host: 172.16.0.0
X-Forwarded-Host: /admin/console
X-Forwarded-Host: 10.0.0.0
X-Forwarded-Host: 10.0.0.1
X-Forwarded-Host: 127.0.0.1
X-Forwarded-Host: 127.0.0.1:443
X-Forwarded-Host: 127.0.0.1:80
X-Forwarded-Host: 172.16.0.0
X-Original-URL: /admin/console
X-Original-URL: 10.0.0.0
X-Original-URL: 10.0.0.1
X-Original-URL: 127.0.0.1
X-Original-URL: 127.0.0.1:443
X-Original-URL: 127.0.0.1:80
X-Original-URL: 172.16.0.0
X-Rewrite-URL: /admin/console
X-Rewrite-URL: 10.0.0.0
X-Rewrite-URL: 10.0.0.1
X-Rewrite-URL: 127.0.0.1
X-Rewrite-URL: 127.0.0.1:443
X-Rewrite-URL: 127.0.0.1:80
X-Rewrite-URL: 172.16.0.0
Content-Length: /admin/console
Content-Length: 10.0.0.0
Content-Length: 10.0.0.1
Content-Length: 127.0.0.1
Content-Length: 127.0.0.1:443
Content-Length: 127.0.0.1:80
Content-Length: 172.16.0.0
X-ProxyUser-Ip: /admin/console
X-ProxyUser-Ip: 10.0.0.0
X-ProxyUser-Ip: 10.0.0.1
X-ProxyUser-Ip: 127.0.0.1
X-ProxyUser-Ip: 127.0.0.1:443
X-ProxyUser-Ip: 127.0.0.1:80
X-ProxyUser-Ip: 172.16.0.0
Base-Url: /admin/console
Base-Url: 10.0.0.0
Base-Url: 10.0.0.1
Base-Url: 127.0.0.1
Base-Url: 127.0.0.1:443
Base-Url: 127.0.0.1:80
Base-Url: 172.16.0.0
Client-IP: /admin/console
Client-IP: 10.0.0.0
Client-IP: 10.0.0.1
Client-IP: 127.0.0.1
Client-IP: 127.0.0.1:443
Client-IP: 127.0.0.1:80
Client-IP: 172.16.0.0
Http-Url: /admin/console
Http-Url: 10.0.0.0
Http-Url: 10.0.0.1
Http-Url: 127.0.0.1
Http-Url: 127.0.0.1:443
Http-Url: 127.0.0.1:80
Http-Url: 172.16.0.0
Proxy-Host: /admin/console
Proxy-Host: 10.0.0.0
Proxy-Host: 10.0.0.1
Proxy-Host: 127.0.0.1
Proxy-Host: 127.0.0.1:443
Proxy-Host: 127.0.0.1:80
Proxy-Host: 172.16.0.0
Proxy-Url: /admin/console
Proxy-Url: 10.0.0.0
Proxy-Url: 10.0.0.1
Proxy-Url: 127.0.0.1
Proxy-Url: 127.0.0.1:443
Proxy-Url: 127.0.0.1:80
Proxy-Url: 172.16.0.0
Real-Ip: /admin/console
Real-Ip: 10.0.0.0
Real-Ip: 10.0.0.1
Real-Ip: 127.0.0.1
Real-Ip: 127.0.0.1:443
Real-Ip: 127.0.0.1:80
Real-Ip: 172.16.0.0
Redirect: /admin/console
Redirect: 10.0.0.0
Redirect: 10.0.0.1
Redirect: 127.0.0.1
Redirect: 127.0.0.1:443
Redirect: 127.0.0.1:80
Redirect: 172.16.0.0
Referrer: /admin/console
Referrer: 10.0.0.0
Referrer: 10.0.0.1
Referrer: 127.0.0.1
Referrer: 127.0.0.1:443
Referrer: 127.0.0.1:80
Referrer: 172.16.0.0
Request-Uri: /admin/console
Request-Uri: 10.0.0.0
Request-Uri: 10.0.0.1
Request-Uri: 127.0.0.1
Request-Uri: 127.0.0.1:443
Request-Uri: 127.0.0.1:80
Request-Uri: 172.16.0.0
Uri: /admin/console
Uri: 10.0.0.0
Uri: 10.0.0.1
Uri: 127.0.0.1
Uri: 127.0.0.1:443
Uri: 127.0.0.1:80
Uri: 172.16.0.0
Url: /admin/console
Url: 10.0.0.0
Url: 10.0.0.1
Url: 127.0.0.1
Url: 127.0.0.1:443
Url: 127.0.0.1:80
Url: 172.16.0.0
X-Forward-For: /admin/console
X-Forward-For: 10.0.0.0
X-Forward-For: 10.0.0.1
X-Forward-For: 127.0.0.1
X-Forward-For: 127.0.0.1:443
X-Forward-For: 127.0.0.1:80
X-Forward-For: 172.16.0.0
X-Forwarded-By: /admin/console
X-Forwarded-By: 10.0.0.0
X-Forwarded-By: 10.0.0.1
X-Forwarded-By: 127.0.0.1
X-Forwarded-By: 127.0.0.1:443
X-Forwarded-By: 127.0.0.1:80
X-Forwarded-By: 172.16.0.0
X-Forwarded-For-Original: /admin/console
X-Forwarded-For-Original: 10.0.0.0
X-Forwarded-For-Original: 10.0.0.1
X-Forwarded-For-Original: 127.0.0.1
X-Forwarded-For-Original: 127.0.0.1:443
X-Forwarded-For-Original: 127.0.0.1:80
X-Forwarded-For-Original: 172.16.0.0
X-Forwarded-Server: /admin/console
X-Forwarded-Server: 10.0.0.0
X-Forwarded-Server: 10.0.0.1
X-Forwarded-Server: 127.0.0.1
X-Forwarded-Server: 127.0.0.1:443
X-Forwarded-Server: 127.0.0.1:80
X-Forwarded-Server: 172.16.0.0
X-Forwarded: /admin/console
X-Forwarded: 10.0.0.0
X-Forwarded: 10.0.0.1
X-Forwarded: 127.0.0.1
X-Forwarded: 127.0.0.1:443
X-Forwarded: 127.0.0.1:80
X-Forwarded: 172.16.0.0
X-Forwarder-For: /admin/console
X-Forwarder-For: 10.0.0.0
X-Forwarder-For: 10.0.0.1
X-Forwarder-For: 127.0.0.1
X-Forwarder-For: 127.0.0.1:443
X-Forwarder-For: 127.0.0.1:80
X-Forwarder-For: 172.16.0.0
X-Http-Destinationurl: /admin/console
X-Http-Destinationurl: 10.0.0.0
X-Http-Destinationurl: 10.0.0.1
X-Http-Destinationurl: 127.0.0.1
X-Http-Destinationurl: 127.0.0.1:443
X-Http-Destinationurl: 127.0.0.1:80
X-Http-Destinationurl: 172.16.0.0
X-Http-Host-Override: /admin/console
X-Http-Host-Override: 10.0.0.0
X-Http-Host-Override: 10.0.0.1
X-Http-Host-Override: 127.0.0.1
X-Http-Host-Override: 127.0.0.1:443
X-Http-Host-Override: 127.0.0.1:80
X-Http-Host-Override: 172.16.0.0
X-Original-Remote-Addr: /admin/console
X-Original-Remote-Addr: 10.0.0.0
X-Original-Remote-Addr: 10.0.0.1
X-Original-Remote-Addr: 127.0.0.1
X-Original-Remote-Addr: 127.0.0.1:443
X-Original-Remote-Addr: 127.0.0.1:80
X-Original-Remote-Addr: 172.16.0.0
X-Proxy-Url: /admin/console
X-Proxy-Url: 10.0.0.0
X-Proxy-Url: 10.0.0.1
X-Proxy-Url: 127.0.0.1
X-Proxy-Url: 127.0.0.1:443
X-Proxy-Url: 127.0.0.1:80
X-Proxy-Url: 172.16.0.0
X-Real-Ip: /admin/console
X-Real-Ip: 10.0.0.0
X-Real-Ip: 10.0.0.1
X-Real-Ip: 127.0.0.1
X-Real-Ip: 127.0.0.1:443
X-Real-Ip: 127.0.0.1:80
X-Real-Ip: 172.16.0.0
X-Remote-Addr: /admin/console
X-Remote-Addr: 10.0.0.0
X-Remote-Addr: 10.0.0.1
X-Remote-Addr: 127.0.0.1
X-Remote-Addr: 127.0.0.1:443
X-Remote-Addr: 127.0.0.1:80
X-Remote-Addr: 172.16.0.0
X-OReferrer: /admin/console
X-OReferrer: 10.0.0.0
X-OReferrer: 10.0.0.1
X-OReferrer: 127.0.0.1
X-OReferrer: 127.0.0.1:443
X-OReferrer: 127.0.0.1:80
X-OReferrer: 172.16.0.0
X-Originating-IP: /admin/console
X-Originating-IP: 10.0.0.0
X-Originating-IP: 10.0.0.1
X-Originating-IP: 127.0.0.1
X-Originating-IP: 127.0.0.1:443
X-Originating-IP: 127.0.0.1:80
X-Originating-IP: 172.16.0.0
X-Forwarded-For: /admin/console
X-Forwarded-For: 10.0.0.0
X-Forwarded-For: 10.0.0.1
X-Forwarded-For: 127.0.0.1
X-Forwarded-For: 127.0.0.1:443
X-Forwarded-For: 127.0.0.1:80
X-Forwarded-For: 172.16.0.0
X-Forwarded: /admin/console
X-Forwarded: 10.0.0.0
X-Forwarded: 10.0.0.1
X-Forwarded: 127.0.0.1
X-Forwarded: 127.0.0.1:443
X-Forwarded: 127.0.0.1:80
X-Forwarded: 172.16.0.0
Forwarded-For: /admin/console
Forwarded-For: 10.0.0.0
Forwarded-For: 10.0.0.1
Forwarded-For: 127.0.0.1
Forwarded-For: 127.0.0.1:443
Forwarded-For: 127.0.0.1:80
Forwarded-For: 172.16.0.0
X-Remote-IP: /admin/console
X-Remote-IP: 10.0.0.0
X-Remote-IP: 10.0.0.1
X-Remote-IP: 127.0.0.1
X-Remote-IP: 127.0.0.1:443
X-Remote-IP: 127.0.0.1:80
X-Remote-IP: 172.16.0.0
X-Remote-Addr: /admin/console
X-Remote-Addr: 10.0.0.0
X-Remote-Addr: 10.0.0.1
X-Remote-Addr: 127.0.0.1
X-Remote-Addr: 127.0.0.1:443
X-Remote-Addr: 127.0.0.1:80
X-Remote-Addr: 172.16.0.0
X-ProxyUser-Ip: /admin/console
X-ProxyUser-Ip: 10.0.0.0
X-ProxyUser-Ip: 10.0.0.1
X-ProxyUser-Ip: 127.0.0.1
X-ProxyUser-Ip: 127.0.0.1:443
X-ProxyUser-Ip: 127.0.0.1:80
X-ProxyUser-Ip: 172.16.0.0
X-Original-URL: /admin/console
X-Original-URL: 10.0.0.0
X-Original-URL: 10.0.0.1
X-Original-URL: 127.0.0.1
X-Original-URL: 127.0.0.1:443
X-Original-URL: 127.0.0.1:80
X-Original-URL: 172.16.0.0
Client-IP: /admin/console
Client-IP: 10.0.0.0
Client-IP: 10.0.0.1
Client-IP: 127.0.0.1
Client-IP: 127.0.0.1:443
Client-IP: 127.0.0.1:80
Client-IP: 172.16.0.0
True-Client-IP: /admin/console
True-Client-IP: 10.0.0.0
True-Client-IP: 10.0.0.1
True-Client-IP: 127.0.0.1
True-Client-IP: 127.0.0.1:443
True-Client-IP: 127.0.0.1:80
True-Client-IP: 172.16.0.0
Cluster-Client-IP: /admin/console
Cluster-Client-IP: 10.0.0.0
Cluster-Client-IP: 10.0.0.1
Cluster-Client-IP: 127.0.0.1
Cluster-Client-IP: 127.0.0.1:443
Cluster-Client-IP: 127.0.0.1:80
Cluster-Client-IP: 172.16.0.0
X-ProxyUser-Ip: /admin/console
X-ProxyUser-Ip: 10.0.0.0
X-ProxyUser-Ip: 10.0.0.1
X-ProxyUser-Ip: 127.0.0.1
X-ProxyUser-Ip: 127.0.0.1:443
X-ProxyUser-Ip: 127.0.0.1:80
X-ProxyUser-Ip: 172.16.0.0
Host: /admin/console
Host: 10.0.0.0
Host: 10.0.0.1
Host: 127.0.0.1
Host: 127.0.0.1:443
Host: 127.0.0.1:80
Host: 172.16.0.0
X-Original-URL: /admin/console
X-Original-URL: 10.0.0.0
X-Original-URL: 10.0.0.1
X-Original-URL: 127.0.0.1
X-Original-URL: 127.0.0.1:443
X-Original-URL: 127.0.0.1:80
X-Original-URL: 172.16.0.0
X-Rewrite-URL: /admin/console
X-Rewrite-URL: 10.0.0.0
X-Rewrite-URL: 10.0.0.1
X-Rewrite-URL: 127.0.0.1
X-Rewrite-URL: 127.0.0.1:443
X-Rewrite-URL: 127.0.0.1:80
X-Rewrite-URL: 172.16.0.0
Forwarded: /admin/console
Forwarded: 10.0.0.0
Forwarded: 10.0.0.1
Forwarded: 127.0.0.1
Forwarded: 127.0.0.1:443
Forwarded: 127.0.0.1:80
Forwarded: 172.16.0.0
Via: /admin/console
Via: 10.0.0.0
Via: 10.0.0.1
Via: 127.0.0.1
Via: 127.0.0.1:443
Via: 127.0.0.1:80
Via: 172.16.0.0""".split('\n')

raw_headers='''X-Originally-Forwarded-For
X-Originating-
X-Originating-IP
True-Client-IP
X-WAP-Profile
From
Profile
X-Arbitrary
X-HTTP-DestinationURL
X-Forwarded-Proto
Destination
Proxy
CF-Connecting-IP
Referer
X-Custom-IP-Authorization
X-Custom-IP-Authorization..;/
X-Originating-IP
X-Forwarded-For
X-Remote-IP
X-Client-IP
X-Host
X-Forwarded-Host
X-Original-URL
X-Rewrite-URL
Content-Length
X-ProxyUser-Ip
Base-Url
Client-IP
Http-Url
Proxy-Host
Proxy-Url
Real-Ip
Redirect
Referrer
Request-Uri
Uri
Url
X-Forward-For
X-Forwarded-By
X-Forwarded-For-Original
X-Forwarded-Server
X-Forwarded
X-Forwarder-For
X-Http-Destinationurl
X-Http-Host-Override
X-Original-Remote-Addr
X-Proxy-Url
X-Real-Ip
X-Remote-Addr
X-OReferrer
X-Originating-IP
X-Forwarded-For
X-Forwarded
Forwarded-For
X-Remote-IP
X-Remote-Addr
X-ProxyUser-Ip
X-Original-URL
Client-IP
True-Client-IP
Cluster-Client-IP
X-ProxyUser-Ip
Host
X-Original-URL
X-Rewrite-URL
Forwarded
Via'''.split('\n')

# %%
import requests
import socket

def Headers_Fuzzing(target,Headers,raw_headers,response_headers) :
    print("Fuzzing Headers...")
    for header in Headers :
        try:
            headers_dict = {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
            }
            header = header.strip()
            key, value = header.split(": ",1)
            headers_dict[key] = value
            response = requests.get(target,headers=headers_dict)
            content_length = len(response.text)
            for headerr, value in response.headers.items() :
                if headerr not in response_headers or value not in response_headers: 
                    response_headers[headerr] = value
            if response.status_code == 200 :
                print(f"{response.status_code}    {header} | length : [ {content_length} ]")
                print(f"Intercept the request from this URL : {target} in Burp or OWASPzap and add this header : {header}")
            else :
                # print(f"[ {response.status_code} ]    {header} | length : [ {content_length} ]")
                pass
        except Exception as e:
            print(f"{e} {header}")

    
    adresse_type="net"
    # Fuzzing Headers Part 2
    for header in raw_headers :
        try:
            domain = target[target.index("/")+2:target.index(adresse_type)+3]
            ip_address = socket.gethostbyname(domain)
            headerr = { header.strip() : ip_address }
            response = requests.get(target,headers=headerr)
            content_length = len(response.text)
            if response.status_code == 200 :
                print(f" {response.status_code}   {header.strip()}: {ip_address} | length : {content_length}")
                print(f"Intercept the request from this URL : {target} in Burp or OWASPzap and add this header : {header}:{ip_address}")
            else :
                # print(f"[ {response.status_code} ]    {header} | length : [ {content_length} ]")
                pass
        except socket.gaierror:
            print(f"Could not resolve the domain: {domain}")

# %%
url="https://touch.dofusbook.net/stuffs/touch/public/?page=1&user=248432-db&sort=update-desc"
Headers_Fuzzing(url,headers_val,raw_headers,{})
# Out:
# Fuzzing Headers...

# %%
req.get("https://d-bk.net/fr/t/Cqpq")
# Out:
# <Response [403]>

# %%
headers_sele = driver.execute_script("""
    var req = window.performance.getEntries().find(e => e.name.includes('stuffs/touch/public'));
    return req ? req : {};
""")
print(headers_sele)
# Out:
# {'activationStart': 0, 'connectEnd': 25.625, 'connectStart': 11.634999997913837, 'criticalCHRestart': 0, 'decodedBodySize': 20803, 'deliveryType': '', 'domComplete': 106.95499999821186, 'domContentLoadedEventEnd': 106.78999999910593, 'domContentLoadedEventStart': 106.78499999642372, 'domInteractive': 106.77499999850988, 'domainLookupEnd': 11.634999997913837, 'domainLookupStart': 0.7199999988079071, 'duration': 106.96000000089407, 'encodedBodySize': 4620, 'entryType': 'navigation', 'fetchStart': 0.35499999672174454, 'finalResponseHeadersStart': 89.8449999988079, 'firstInterimResponseStart': 0, 'initiatorType': 'navigation', 'loadEventEnd': 106.96000000089407, 'loadEventStart': 106.96000000089407, 'name': 'https://touch.dofusbook.net/stuffs/touch/public/?page=1&user=248432-db&sort=update-desc', 'nextHopProtocol': 'h3', 'notRestoredReasons': None, 'redirectCount': 0, 'redirectEnd': 0, 'redirectStart': 0, 'renderBlockingStatus': 'non-blocking', 'requestStart': 25.695000000298023, 'respon
# ...

# %%
# Récupérer le user agent depuis Selenium
user_agent = driver.execute_script("return navigator.userAgent;")
cookies = {c['name']: c['value'] for c in driver.get_cookies()}

headers = {
    "User-Agent": user_agent,
    "Accept": "application/json,text/plain,*/*",
    "Referer": "https://touch.dofusbook.net/"
}

# Faire la requête avec les cookies Selenium
response = req.get(url, headers=headers, cookies=cookies)

# %%
response
# Out:
# <Response [403]>

# %%
headers_copiés_raw="""Host: touch.dofusbook.net
User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:142.0) Gecko/20100101 Firefox/142.0
'Accept': 'application/json, text/plain, */*'
Accept-Language: fr,fr-FR;q=0.8,en-US;q=0.5,en;q=0.3
Accept-Encoding: gzip, deflate, br, zstd
DNT: 1
Alt-Used: touch.dofusbook.net
Connection: keep-alive
Cookie: jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6OTk2MjQ0LCJuYW1lIjoiTWV0YVBhbm8iLCJpc19wcmVtaXVtIjpmYWxzZSwibGFzdF92aXNpdCI6IjIwMjUtMDktMTEiLCJleG9fZW5hYmxlZCI6ZmFsc2UsImlhdCI6MTc1NzU5OTMzMSwiZXhwIjoxNzYwMTkxMzMxLCJhdWQiOiJkb2Z1c2Jvb2submV0IiwiaXNzIjoiYXV0aC5kb2Z1c2Jvb2submV0In0._WMa0wkAWgELTa9CvLaI2NyAHLbiOHrxPXwxpwrdFCI; autoLogin=true
Upgrade-Insecure-Requests: 1
Sec-Fetch-Dest: document
Sec-Fetch-Mode: navigate
Sec-Fetch-Site: none
Sec-Fetch-User: ?1
If-None-Match: W/"5143-5q/dt/IH7IVceqxxn1x0qnjTdQk"
Priority: u=0, i
TE: trailers""".split("\n")

headers_copiés=dict()
for hd in headers_copiés_raw:
    key, value = hd.split(": ",1)
    headers_copiés[key]=value
headers_copiés
# Out:
# {'Host': 'touch.dofusbook.net',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:142.0) Gecko/20100101 Firefox/142.0',
#  "'Accept'": "'application/json, text/plain, */*'",
#  'Accept-Language': 'fr,fr-FR;q=0.8,en-US;q=0.5,en;q=0.3',
#  'Accept-Encoding': 'gzip, deflate, br, zstd',
#  'DNT': '1',
#  'Alt-Used': 'touch.dofusbook.net',
#  'Connection': 'keep-alive',
#  'Cookie': 'jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6OTk2MjQ0LCJuYW1lIjoiTWV0YVBhbm8iLCJpc19wcmVtaXVtIjpmYWxzZSwibGFzdF92aXNpdCI6IjIwMjUtMDktMTEiLCJleG9fZW5hYmxlZCI6ZmFsc2UsImlhdCI6MTc1NzU5OTMzMSwiZXhwIjoxNzYwMTkxMzMxLCJhdWQiOiJkb2Z1c2Jvb2submV0IiwiaXNzIjoiYXV0aC5kb2Z1c2Jvb2submV0In0._WMa0wkAWgELTa9CvLaI2NyAHLbiOHrxPXwxpwrdFCI; autoLogin=true',
#  'Upgrade-Insecure-Requests': '1',
#  'Sec-Fetch-Dest': 'document',
#  'Sec-Fetch-Mode': 'navigate',
#  'Sec-Fetch-Site': 'none',
#  'Sec-Fetch-User': '?1',
#  'If-None-Match': 'W/"5143-5q/dt/IH7IVceqxxn1x0qnjTdQk"',
#  'Priority': 'u=0, i',
# ...

# %%
# Lancer Selenium
chrome_options = Options()
driver = webdriver.Chrome(options=chrome_options)

url = "https://touch.dofusbook.net/stuffs/touch/public/?page=1&user=248432-db&sort=update-desc"
driver.get(url)

# Récupérer les cookies du navigateur
cookies_selenium = {c['name']: c['value'] for c in driver.get_cookies()}

# Fermer Selenium
driver.quit()

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:142.0) Gecko/20100101 Firefox/142.0',
    'Accept': 'application/json, text/plain, */*',
    'Referer': 'https://touch.dofusbook.net/',
    'Connection': 'keep-alive'
}
response = req.get(url, headers=headers)
response
# Out:
# <Response [403]>

# %%
# %pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------------- ---------- 1.3/1.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 8.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# from seleniumwire import webdriver

driver = webdriver.Chrome()

driver.get(url)

for request in driver.requests:
    if "stuffs/touch/public" in request.url and request.response:
        print("URL:", request.url)
        print("HEADERS:", request.headers)
        print("COOKIES:", request.headers.get('Cookie'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 7
#       3 driver = webdriver.Chrome()
#       5 driver.get(url)
# ----> 7 for request in driver.requests:
#       8     if "stuffs/touch/public" in request.url and request.response:
#       9         print("URL:", request.url)
#
# AttributeError: 'WebDriver' object has no attribute 'requests'

# %%
test="""accept
text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7
accept-encoding
gzip, deflate, br, zstd
accept-language
fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
cache-control
max-age=0
if-none-match
W/"5143-fGN7mokK020CIxZt+D/C56VnTcU"
priority
u=0, i
sec-ch-ua
"Not;A=Brand";v="99", "Google Chrome";v="139", "Chromium";v="139"
sec-ch-ua-mobile
?0
sec-ch-ua-platform
"Windows"
sec-fetch-dest
document
sec-fetch-mode
navigate
sec-fetch-site
none
sec-fetch-user
?1
upgrade-insecure-requests
1
user-agent
Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36""".split("\n")
test_dic={}
for i in range(len(test)//2):
    test_dic[test[2*i]]=test[2*i+1]
test_dic
# Out:
# {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#  'accept-encoding': 'gzip, deflate, br, zstd',
#  'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
#  'cache-control': 'max-age=0',
#  'if-none-match': 'W/"5143-fGN7mokK020CIxZt+D/C56VnTcU"',
#  'priority': 'u=0, i',
#  'sec-ch-ua': '"Not;A=Brand";v="99", "Google Chrome";v="139", "Chromium";v="139"',
#  'sec-ch-ua-mobile': '?0',
#  'sec-ch-ua-platform': '"Windows"',
#  'sec-fetch-dest': 'document',
#  'sec-fetch-mode': 'navigate',
#  'sec-fetch-site': 'none',
#  'sec-fetch-user': '?1',
#  'upgrade-insecure-requests': '1',
#  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36'}

# %%
response = req.get(url, headers=test_dic)
response
# Out:
# <Response [403]>

# %%
import undetected_chromedriver as uc
import json
import time

options = uc.ChromeOptions()
# options.headless = True  # reste headless mais furtif

# options.add_argument("--headless")  # Run in headless mode

options.add_argument("--no-sandbox")
options.add_argument("--disable-blink-features=AutomationControlled")

driver = uc.Chrome(options=options)

url = "https://touch.dofusbook.net/stuffs/touch/public/?page=1&user=248432-db&sort=update-desc"
driver.get(url)

# Attendre un peu que Cloudflare valide la session
time.sleep(3)

# Récupérer le JSON dans le <pre>
pre_text = driver.find_element("tag name", "pre").text
data = json.loads(pre_text)
print(data)

driver.quit()

# driver.page_source
# Out:
# {'source': 'database', 'count': 217, 'rows': [{'avatar': '40_1', 'slug': '1809093-12-6-6-invo-no-cc', 'elapsed_time': '28 min', 'elapsed_time_long': '28 minutes', 'allowed_classes': [4, 2, 5, 6, 7, 14, 13, 12, 11, 9, 8], 'tags': ['air', 'pvp'], 'id': 1809093, 'character_class': 4, 'character_gender': 0, 'folder_id': 60240, 'name': '12/6 6 invo no cc', 'visible': True, 'updated_at': '2025-09-11T15:39:11.000Z', 'stuffItem': {'a1': 4258, 'a2': 4231, 'am': 3915, 'ar': 3309, 'bo': 4047, 'br': 3480, 'ca': 3767, 'ce': 904, 'ch': 3596, 'd1': 548, 'd2': 92, 'd3': 524, 'd4': 71, 'd5': 636, 'd6': 1725, 'fa': 3090, 'mo': None}, 'stat': {'views': 196, 'level': 0, 'pa': 0, 'pm': 0}, 'folder': {'name': 'Stuff air'}, 'skin': None}, {'avatar': '60_1', 'slug': '2188367-12-6-6-do-crit', 'elapsed_time': '31 min', 'elapsed_time_long': '31 minutes', 'allowed_classes': [6, 7, 5, 4, 2, 8, 9, 11, 12, 13, 14], 'tags': ['air', 'pvp'], 'id': 2188367, 'character_class': 6, 'character_gender': 0, 'folder_id': 602
# ...

# %%
# import requests as req
# import pandas as pd

# from bs4 import BeautifulSoup

# from selenium import webdriver
# from selenium.webdriver.chrome.options import Options

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import json

# chrome_options = Options()
# chrome_options.add_argument("--headless")  # Run in headless mode
# driver = webdriver.Chrome(options=chrome_options)

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# driver = webdriver.Chrome()

headers={'Accept': 'application/json, text/plain, */*',}

url="https://touch.dofusbook.net/stuffs/touch/public/?page=1&user=248432-db&sort=update-desc"
driver.get(url)
try:
    pre_text = driver.find_element("tag name", "pre").text
    data = json.loads(pre_text)
    print(data)
except Exception as e:
    print(e)
    print(driver.page_source)
# driver.quit()
# Out:
# {'source': 'database', 'count': 221, 'rows': [{'avatar': '70_1', 'slug': '3103631-allclass-m-200', 'elapsed_time': '5 j', 'elapsed_time_long': '5 jours', 'allowed_classes': [], 'tags': [], 'id': 3103631, 'character_class': 7, 'character_gender': 0, 'folder_id': None, 'name': 'AllClass M 200', 'visible': True, 'updated_at': '2025-09-29T18:53:32.000Z', 'stuffItem': {'a1': 6704, 'a2': 6703, 'am': 5235, 'ar': 4855, 'bo': 4960, 'br': 6724, 'ca': 3373, 'ce': 5234, 'ch': 5233, 'd1': 548, 'd2': 92, 'd3': 1725, 'd4': 93, 'd5': 636, 'd6': 524, 'fa': 3090, 'mo': None}, 'stat': {'views': 35, 'level': 0, 'pa': 0, 'pm': 0}, 'folder': None, 'skin': None}, {'avatar': '100_1', 'slug': '3126059-sadida-m-200', 'elapsed_time': '8 j', 'elapsed_time_long': '8 jours', 'allowed_classes': [10], 'tags': [], 'id': 3126059, 'character_class': 10, 'character_gender': 0, 'folder_id': None, 'name': 'Sadida M 200', 'visible': True, 'updated_at': '2025-09-26T11:41:13.000Z', 'stuffItem': {'a1': 5033, 'a2': 4230, 'am'
# ...

# %%
url="https://touch.dofusbook.net/stuffs/touch/public/?page=1&user=996244-db&sort=update-desc"
driver.get(url)
try:
    pre_text = driver.find_element("tag name", "pre").text
    data = json.loads(pre_text)
    print(data)
except Exception as e:
    print(e)
    print(driver.page_source)
# Out:
# {'source': 'database', 'count': 80, 'rows': [{'avatar': '140_1', 'slug': '3063038-crocs-noirs', 'elapsed_time': '17 h', 'elapsed_time_long': '17 heures', 'allowed_classes': [], 'tags': ['air', 'ter', 'rp'], 'id': 3063038, 'character_class': 14, 'character_gender': 0, 'folder_id': None, 'name': 'crocs noirs', 'visible': True, 'updated_at': '2025-09-10T22:47:31.000Z', 'stuffItem': {'a1': 6710, 'a2': 5185, 'am': 6707, 'ar': 6701, 'bo': 6708, 'br': 6724, 'ca': 6706, 'ce': 6709, 'ch': 6705, 'd1': 1725, 'd2': 92, 'd3': 71, 'd4': 1559, 'd5': 1822, 'd6': 5238, 'fa': 4683, 'mo': None}, 'stat': {'views': 33, 'level': 0, 'pa': 0, 'pm': 0}, 'folder': None, 'skin': None}, {'avatar': '70_1', 'slug': '3105455-ava-croc-noir', 'elapsed_time': '17 h', 'elapsed_time_long': '17 heures', 'allowed_classes': [7, 6, 5, 14, 12, 11, 9, 8, 4, 13, 2], 'tags': ['air', 'rp'], 'id': 3105455, 'character_class': 7, 'character_gender': 0, 'folder_id': None, 'name': 'ava croc noir', 'visible': True, 'updated_at': '202
# ...

# %%
data["rows"]
# Out:
# [{'avatar': '40_1',
#   'slug': '1809093-12-6-6-invo-no-cc',
#   'elapsed_time': '33 min',
#   'elapsed_time_long': '33 minutes',
#   'allowed_classes': [4, 2, 5, 6, 7, 14, 13, 12, 11, 9, 8],
#   'tags': ['air', 'pvp'],
#   'id': 1809093,
#   'character_class': 4,
#   'character_gender': 0,
#   'folder_id': 60240,
#   'name': '12/6 6 invo no cc',
#   'visible': True,
#   'updated_at': '2025-09-11T15:39:11.000Z',
#   'stuffItem': {'a1': 4258,
#    'a2': 4231,
#    'am': 3915,
#    'ar': 3309,
#    'bo': 4047,
#    'br': 3480,
#    'ca': 3767,
#    'ce': 904,
#    'ch': 3596,
#    'd1': 548,
#    'd2': 92,
#    'd3': 524,
#    'd4': 71,
#    'd5': 636,
#    'd6': 1725,
#    'fa': 3090,
#    'mo': None},
#   'stat': {'views': 196, 'level': 0, 'pa': 0, 'pm': 0},
#   'folder': {'name': 'Stuff air'},
#   'skin': None},
#  {'avatar': '60_1',
#   'slug': '2188367-12-6-6-do-crit',
#   'elapsed_time': '36 min',
#   'elapsed_time_long': '36 minutes',
# ...

# %%
url="https://www.dofusbook.net/stuffs/dofus/public/?page=1&user=84161-punshounet"
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

driver.get(url)
try:
    pre_text = driver.find_element("tag name", "pre").text
    data = json.loads(pre_text)
    print(data)
except Exception as e:
    print(e)
    print(driver.page_source)
# Out:
# {'source': 'database', 'count': 368, 'rows': [{'avatar': '11_1', 'slug': '20751727-terre-6-invos', 'elapsed_time': '18 j', 'elapsed_time_long': '18 jours', 'allowed_classes': [], 'tags': ['ter', 'pvm', 'ic'], 'id': 20751727, 'character_class': 1, 'character_gender': 1, 'folder_id': 1620544, 'name': 'Terre 6 Invos', 'visible': True, 'updated_at': '2025-09-16T18:51:59.000Z', 'stuffItem': {'a1': 3176, 'a2': 5270, 'am': 5266, 'ar': 5271, 'bo': 3177, 'br': 5272, 'ca': 2825, 'ce': 5268, 'ch': 3175, 'd1': 3652, 'd2': 236, 'd3': 2829, 'd4': 257, 'd5': 5123, 'd6': 2734, 'fa': 2271, 'mo': None}, 'stat': {'views': 138, 'level': 0, 'pa': 0, 'pm': 0}, 'folder': {'name': '2 Exo'}, 'skin': None}, {'avatar': '11_1', 'slug': '20751807-terre-6-invos', 'elapsed_time': '18 j', 'elapsed_time_long': '18 jours', 'allowed_classes': [], 'tags': ['ter', 'pvm', 'ic'], 'id': 20751807, 'character_class': 1, 'character_gender': 1, 'folder_id': 1620542, 'name': 'Terre 6 Invos', 'visible': True, 'updated_at': '2025
# ...

# %%
FR_KEYS=['Lvl','PA', 'PM', 'PO', 'Initiative', 'Critique', 'Invocation', 'Soin', 'Vitalité', 'Sagesse', 'Force', 'Intelligence', 'Chance', 'Agilité', 'Puissance', 'Fuite', 'Esq. PA', 'Esq. PM', 'Pods', 'Tacle', 'Ret. PA', 'Ret. PM',  'Do Critique', '% Ré Air', '% Ré Feu', 'Do Eau', 'Do Terre', 'Do Neutre', '% Ré Terre', 'Prospection', 'Do Feu', 'Do Air', 'Do Poussée', 'Ré Neutre', '% Ré Neutre', 'Ré Terre', 'Ré Feu', 'Ré Eau', '% Ré Eau', 'Ré Air', 'Ré Critique', 'Ré Poussée', "Do"]
EN_KEYS=['Lvl','AP', 'MP', 'Range', 'Initiative', 'Critical', 'Summon', 'Heal', 'Vitality', 'Wisdom', 'Strength', 'Intelligence', 'Chance', 'Agility', 'Power', 'Dodge', 'AP Res.', 'MP Res.', 'Pods', 'Lock', 'AP Red', 'MP Red',  'Da Critical', '% Re Air', '% Re Fire', 'Da Water', 'Da Earth', 'Da Neutral', '% Re Earth', 'Prospecting', 'Da Fire', 'Da Air', 'Da Pushback', 'Re Neutral', '% Re Neutral', 'Re Earth', 'Re Fire', 'Re Water', '% Re Water', 'Re Air', 'Re Critical', 'Re Pushback', "Da"]
ES_KEYS=['Lvl','PA', 'PM', 'AL', 'Iniciativa', 'Crítico', 'Invocación', 'Cura', 'Vitalidad', 'Sabiduría', 'Fuerza', 'Inteligencia', 'Suerte', 'Agilidad', 'Potencia', 'Huida', 'Esq. PA', 'Esq. PM', 'Pods', 'Placaje', 'Ret. PA', 'Ret. PM',  'Da Crítico', '% Re Aire', '% Re Fuego', 'Da Agua', 'Da Tierra', 'Da Neutro', '% Re Tierra', 'Prospección', 'Da Fuego', 'Da Aire', 'Da Empuje', 'Re Neutro', '% Re Neutro', 'Re Tierra', 'Re Fuego', 'Re Agua', '% Re Agua', 'Re Aire', 'Re Crítico', 'Re Empuje', "Da"]

ALIASES=dict()
for i in range(len(FR_KEYS)):
    ALIASES[EN_KEYS[i]]=FR_KEYS[i]
    ALIASES[FR_KEYS[i]]=FR_KEYS[i]
    ALIASES[ES_KEYS[i]]=FR_KEYS[i]

TRAD_DB_STATS={
    # stats du perso
    'scroll_vi': 'Vitalité',
    'scroll_sa': 'Sagesse',
    'scroll_fo': 'Force',
    'scroll_in': 'Intelligence',
    'scroll_ch': 'Chance',
    'scroll_ag': 'Agilité',
    'base_vi': 'Vitalité',
    'base_sa': 'Sagesse',
    'base_fo': 'Force',
    'base_in': 'Intelligence',
    'base_ch': 'Chance',
    'base_ag': 'Agilité',

    #fm global
    'pa': "PA",
    'pm': "PM",
    'po': "PO",
    'vi': "Vitalité",
    'sa': "Sagesse",
    'fo': "Force",
    'in': "Intelligence",
    'ch': "Chance",
    'ag': "Agilité",
    'pu': "Puissance",
    'ii': "Initiative",
    'cc': "Critique",
    'ic': "Invocation",
    'so': "Soin",
    'pp': "Prospection",
    'fu': "Fuite",
    'ta': "Tacle",
    'dmg': "Do",
    'dnf': "Do Neutre",
    'dtf': "Do Terre",
    'dff': "Do Feu",
    'def': "Do Eau",
    'daf': "Do Air",
    'dc': "Do Critique",
    'dp': "Do Poussée",
    'dw': "non attribué",
    'ds': "non attribué",
    'dm': "non attribué",
    'dd': "non attribué",
    'deg': "non attribué",
    'rn': "Ré Neutre",
    'rt': "Ré Terre",
    'rf': "Ré Feu",
    're': "Ré Eau",
    'ra': "Ré Air",
    'rnp': "% Ré Neutre",
    'rtp': "% Ré Terre",
    'rfp': "% Ré Feu",
    'rep': "% Ré Eau",
    'rap': "% Ré Air",
    'rc': "Ré Critique",
    'rp': "Ré Poussée",
    'rm': "non attribué",
    'rd': "non attribué",
    'rw': "non attribué",
    'epa': "Esq. PA",
    'epm': "Esq. PM",
    'rpa': "Ret. PA",
    'rpm': "Ret. PM",
    'pd': "Pods",
    'pi': "non attribué",
    'pip': "non attribué",
    'rv': "non attribué",
}   
elt_filtre={
    "terre" : "ter"
    ,"feu" : "feu"
    ,"eau" : "eau"
    ,"air" : "air"
    ,"dopou" : "dp"
    ,"cc" : "cc"
    ,"initiative" : "ii"
    ,"pp" : "pp"
    ,"sagesse" : "sa"
    ,"pods" : "pd"
    ,'pvp' : 'pvp'
    ,'pvm' : 'pvm'
    ,'retrait pa' : 'rpa'
    ,'retrait pm' : 'rpm'
    ,'esquive pa' : 'epa'
    ,'esquive pm' : 'epm'
    ,'repou' :'rp'
    ,'recri' : 'rc'
    ,'tank' : 'tank'
    ,'soin' : 'so'
    # ,'dodist' : 'dd'
    # ,'domelee' : 'dm'
    # ,'dosort' : 'ds'
}
raw_elt_to_id={
    elt_filtre['terre']      : 1,
    elt_filtre['feu']        : 2,
    elt_filtre['eau']        : 3,
    elt_filtre['air']        : 4,
    elt_filtre['dopou']      : 5,
    elt_filtre['cc']         : 6,
    elt_filtre['initiative'] : 7,
    elt_filtre['pp']         : 8,
    elt_filtre['sagesse']    : 9,
    elt_filtre['pods']       : 10,
    elt_filtre['pvp']        : 11,
    elt_filtre['pvm']        : 12,
    elt_filtre['retrait pa'] : 13,
    elt_filtre['retrait pm'] : 14,
    elt_filtre['esquive pa'] : 15,
    elt_filtre['esquive pm'] : 16,
    elt_filtre['repou']      : 17,
    elt_filtre['recri']      : 18,
    elt_filtre['tank']       : 19,
    elt_filtre['soin']       : 20
}
classes_filtre={
    "tout" : "A"
    ,"feca" : "1"
    ,"osamodas" : "2"
    ,"enutrof" : "3"
    ,"sram" : "4"
    ,"xelor" : "5"
    ,"ecaflip" : "6"
    ,"eniripsa" : "7"
    ,"iop" : "8"
    ,"cra" : "9"
    ,"sadida" : "10"
    ,'sacrieur' : "11"
    ,"pandawa" : "12"
    ,"roublard" : "13"
    ,"zobal" : "14"
    ,"steamer" : "15"
}

# %%
def get_stats(id,driver):
    
    url="https://www.dofusbook.net/stuffs/dofus/public/"+str(id)
    # data_req= req.get(url)
    data_req=driver.get(url)
    try:
        pre_text = driver.find_element("tag name", "pre").text
        data = json.loads(pre_text)

        # data=data_req.json()
    except:
        print("Erreur lors de la transformation en json dans get_stats")
        print(f"URL = {url}")
        perso={key: -1 for key in FR_KEYS}
        perso["DB_surl"]=-1
        perso["Lvl"]=-1
        perso["db_name"]=-1
        perso["PA"]=-1
        perso["PM"]=-1
        perso["Invocation"]=-1
        perso["Vitalité"]=-1
        return perso
    
    perso={key: -1 for key in FR_KEYS}
    perso_stats=data["stuffStats"] # 1 element = 1 stat
    fmitems=data["fmItems"] # chaque element est un item sous forme dict, chaque element d'un item est un fm qui lui est rajouté
    fmglobal=data["fmGlobal"] #  1 element = 1 stat
    items=data["items"] #list d'items, chaque item est un dict dont la clef "effects" est une liste d'effets où chaque effet est un dict contenant les clefts suivantes 'name': 'nomdelastat','type': 'E', 'min': 0,'max': 0,
    panos=data["cloths"] # list de pano, chaque item est un dict dont la clef "effects" est une liste d'effets où chaque effet est un dict contenant les clefts suivantes 'name': 'nomdelastat','type': 'E', 'value' : 1
    

    
    perso["DB_surl"]=data["stuff"]["short_url"]
    perso["Lvl"]=data["stuff"]["character_level"]
    perso["db_name"]=data["stuff"]["name"]
    perso["PA"]=7
    if perso["Lvl"]<100:
        perso["PA"]-=1
    perso["PM"]=3
    perso["Invocation"]=1
    perso["Vitalité"]=50+5*perso["Lvl"]

    for elt in perso_stats:
        perso[TRAD_DB_STATS[elt]]+=perso_stats[elt]
    
    for elt in fmglobal:
        try:
            perso[TRAD_DB_STATS[elt]]+=fmglobal[elt]
        except:
            pass #au cas où y'a un effet rajouté que je reconnais pas, genre 10% dommages distance, go ignorer
    for item in fmitems:
        for elt in fmitems[item]:
            try:
                perso[TRAD_DB_STATS[elt]]+=fmitems[item][elt]
            except:
                pass #au cas où y'a un effet rajouté que je reconnais pas, genre 10% dommages distance, go ignorer
    for item in items:
        for stat in item["effects"]:
            if stat["type"]=='E':
                if stat["min"]>=0:
                    perso[TRAD_DB_STATS[stat["name"]]]+=stat["max"]
                else:
                    perso[TRAD_DB_STATS[stat["name"]]]+=stat["min"]

    for pano in panos:
        for stat in pano["effects"]:
            if stat["type"]=='E':
                perso[TRAD_DB_STATS[stat["name"]]]+=stat["value"]

    #bonus dérivés de stats
    # perso["Soin"]+=max(0,perso["Intelligence"]/10//1)
    perso["Fuite"]+=max(0,perso["Chance"]/10//1)
    perso["Tacle"]+=max(0,perso["Agilité"]/10//1)
    perso["Esq. PA"]+=max(0,perso["Sagesse"]/10//1)
    perso["Esq. PM"]+=max(0,perso["Sagesse"]/10//1)
    perso["Ret. PA"]+=max(0,perso["Sagesse"]/10//1)
    perso["Ret. PM"]+=max(0,perso["Sagesse"]/10//1)
    perso["Initiative"]+=max(0,perso["Intelligence"])+max(0,perso["Chance"])+max(0,perso["Agilité"])+max(0,perso["Force"])

    return perso

def get_stuff_base_info(id,driver):
    resp=get_stats(id,driver)
    ans={
        "DB_surl": resp["DB_surl"],
        "PA": resp["PA"],
        "PM": resp["PM"],
        "PO": resp["PO"],
        "Invo": resp["Invocation"],
        "Lvl" : resp["Lvl"]
        }
    return ans

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

get_stats("13654074",driver)
get_stuff_base_info("13654074",driver)
# Out:
# {'DB_surl': 'vI30', 'PA': 12, 'PM': 6, 'PO': 5, 'Invo': 2, 'Lvl': 200}

# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
from sqlalchemy.exc import IntegrityError
import requests as req
import json

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import tempfile


def folder_id_finder(folder_name,user):
    base="https://touch.dofusbook.net/stuffs/touch/public/"
    membre="?user="+user+"&sort=update-desc"

    # Crée un dossier temporaire unique pour le profil
    user_data_dir = tempfile.mkdtemp(prefix="selenium_chrome_")
    options = Options()
    options.add_argument(f"--user-data-dir={user_data_dir}")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_argument("--disable-gpu")
    # options.add_argument("--headless=new")
    service = Service("/usr/bin/chromedriver")  # ou /usr/local/bin/chromedriver
    driver = webdriver.Chrome(service=service, options=options)

    driver.get(base+membre)

    try:
        pre_text = driver.find_element("tag name", "pre").text
        resp = json.loads(pre_text)#["rows"]
        # print(resp)
    except Exception as e:
        print("on n'a pas réussi à trouver les données, erreur :",e)
        print(driver.page_source)

    if "folders" not in resp:
        print(f"Erreur : fold_rep=req.get(base+membre).json() a échoué, url ={base+membre}")
        return "-1"
    fold_rep=resp["folders"]
    for fold in fold_rep:
        if fold["name"].lower()==folder_name.lower():
            return str(fold["id"])
    print(f"folder {folder_name} not found in user {user}")
    return "-1"

# %%
resp = folder_id_finder("JDA","244671-warp")

# %%
biblio_id=req.get("https://d-bk.net/fr/tl/11eJ").url.split("/")[-2][:-3]
biblio_id
# Out:
# '244671'

# %% [markdown]
# ADAPTATION DE GET_STATS À DOFUS 3 & RETRO

# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
from sqlalchemy.exc import IntegrityError
import requests as req
import json

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import tempfile

DOFUSBOOK_URL={
    "Dofus Touch"   : "https://touch.dofusbook.net"
    ,"Dofus 3"      : "https://www.dofusbook.net"
    ,"Dofus Retro"  : "https://retro.dofusbook.net"
}
DB_JEU_SHORT={
    "Dofus Touch"   : "touch"
    ,"Dofus 3"      : "dofus"
    ,"Dofus Retro"  : "retro"
}

FR_KEYS=['Lvl','PA', 'PM', 'PO', 'Initiative', 'Critique', 'Invocation', 'Soin', 'Vitalité', 'Sagesse', 'Force', 'Intelligence', 'Chance', 'Agilité', 'Puissance', 'Fuite', 'Esq. PA', 'Esq. PM', 'Pods', 'Tacle', 'Ret. PA', 'Ret. PM',  'Do Critique', '% Ré Air', '% Ré Feu', 'Do Eau', 'Do Terre', 'Do Neutre', '% Ré Terre', 'Prospection', 'Do Feu', 'Do Air', 'Do Poussée', 'Ré Neutre', '% Ré Neutre', 'Ré Terre', 'Ré Feu', 'Ré Eau', '% Ré Eau', 'Ré Air', 'Ré Critique', 'Ré Poussée', "Do"]
EN_KEYS=['Lvl','AP', 'MP', 'Range', 'Initiative', 'Critical', 'Summon', 'Heal', 'Vitality', 'Wisdom', 'Strength', 'Intelligence', 'Chance', 'Agility', 'Power', 'Dodge', 'AP Res.', 'MP Res.', 'Pods', 'Lock', 'AP Red', 'MP Red',  'Da Critical', '% Re Air', '% Re Fire', 'Da Water', 'Da Earth', 'Da Neutral', '% Re Earth', 'Prospecting', 'Da Fire', 'Da Air', 'Da Pushback', 'Re Neutral', '% Re Neutral', 'Re Earth', 'Re Fire', 'Re Water', '% Re Water', 'Re Air', 'Re Critical', 'Re Pushback', "Da"]
ES_KEYS=['Lvl','PA', 'PM', 'AL', 'Iniciativa', 'Crítico', 'Invocación', 'Cura', 'Vitalidad', 'Sabiduría', 'Fuerza', 'Inteligencia', 'Suerte', 'Agilidad', 'Potencia', 'Huida', 'Esq. PA', 'Esq. PM', 'Pods', 'Placaje', 'Ret. PA', 'Ret. PM',  'Da Crítico', '% Re Aire', '% Re Fuego', 'Da Agua', 'Da Tierra', 'Da Neutro', '% Re Tierra', 'Prospección', 'Da Fuego', 'Da Aire', 'Da Empuje', 'Re Neutro', '% Re Neutro', 'Re Tierra', 'Re Fuego', 'Re Agua', '% Re Agua', 'Re Aire', 'Re Crítico', 'Re Empuje', "Da"]

ALIASES=dict()
for i in range(len(FR_KEYS)):
    ALIASES[EN_KEYS[i]]=FR_KEYS[i]
    ALIASES[FR_KEYS[i]]=FR_KEYS[i]
    ALIASES[ES_KEYS[i]]=FR_KEYS[i]

TRAD_DB_STATS={
    # stats du perso
    'scroll_vi': 'Vitalité',
    'scroll_sa': 'Sagesse',
    'scroll_fo': 'Force',
    'scroll_in': 'Intelligence',
    'scroll_ch': 'Chance',
    'scroll_ag': 'Agilité',
    'base_vi': 'Vitalité',
    'base_sa': 'Sagesse',
    'base_fo': 'Force',
    'base_in': 'Intelligence',
    'base_ch': 'Chance',
    'base_ag': 'Agilité',

    #fm global
    'pa': "PA",
    'pm': "PM",
    'po': "PO",
    'vi': "Vitalité",
    'sa': "Sagesse",
    'fo': "Force",
    'in': "Intelligence",
    'ch': "Chance",
    'ag': "Agilité",
    'pu': "Puissance",
    'ii': "Initiative",
    'cc': "Critique",
    'ic': "Invocation",
    'so': "Soin",
    'pp': "Prospection",
    'fu': "Fuite",
    'ta': "Tacle",
    'dmg': "Do",
    'dnf': "Do Neutre",
    'dtf': "Do Terre",
    'dff': "Do Feu",
    'def': "Do Eau",
    'daf': "Do Air",
    'dc': "Do Critique",
    'dp': "Do Poussée",
    'dw': "non attribué",
    'ds': "non attribué",
    'dm': "non attribué",
    'dd': "non attribué",
    'deg': "non attribué",
    'rn': "Ré Neutre",
    'rt': "Ré Terre",
    'rf': "Ré Feu",
    're': "Ré Eau",
    'ra': "Ré Air",
    'rnp': "% Ré Neutre",
    'rtp': "% Ré Terre",
    'rfp': "% Ré Feu",
    'rep': "% Ré Eau",
    'rap': "% Ré Air",
    'rc': "Ré Critique",
    'rp': "Ré Poussée",
    'rm': "non attribué",
    'rd': "non attribué",
    'rw': "non attribué",
    'epa': "Esq. PA",
    'epm': "Esq. PM",
    'rpa': "Ret. PA",
    'rpm': "Ret. PM",
    'pd': "Pods",
    'pi': "non attribué",
    'pip': "non attribué",
    'rv': "non attribué",
}   
def get_stats(id,driver,jeu='Dofus Touch'):
    # TODO : fix les stats, des fois probablement à cause des fm ou autres, les carac vont être trop élevées, des choses doivent être comptées en double genre fm sur un item
    # Je ne les utilise pas pour le moment donc flemme de le faire, mais si on a besoin plus tard y'a ce bug
    url=f"{DOFUSBOOK_URL[jeu]}/api/stuffs/{DB_JEU_SHORT[jeu]}/public/{id}"
    print(url)
    driver.get(url)
    try:
        pre_text = driver.find_element("tag name", "pre").text
        data = json.loads(pre_text)

    except:
        print("Erreur lors de la transformation en json dans get_stats")
        print(f"URL = {url}")
        perso={key: 0 for key in FR_KEYS}
        perso["DB_surl"]=0
        perso["Lvl"]=0
        perso["db_name"]=0
        perso["PA"]=0
        perso["PM"]=0
        perso["Invocation"]=0
        perso["Vitalité"]=0
        return perso
    
    perso={key: 0 for key in FR_KEYS}
    perso_stats=data["stuffStats"] # 1 element = 1 stat
    fmitems=data["fmItems"] # chaque element est un item sous forme dict, chaque element d'un item est un fm qui lui est rajouté
    fmglobal=data["fmGlobal"] #  1 element = 1 stat
    items=data["items"] #list d'items, chaque item est un dict dont la clef "effects" est une liste d'effets où chaque effet est un dict contenant les clefts suivantes 'name': 'nomdelastat','type': 'E', 'min': 0,'max': 0,
    panos=data["cloths"] # list de pano, chaque item est un dict dont la clef "effects" est une liste d'effets où chaque effet est un dict contenant les clefts suivantes 'name': 'nomdelastat','type': 'E', 'value' : 1
    

    
    perso["DB_surl"]=data["stuff"]["short_url"]
    perso["Lvl"]=data["stuff"]["character_level"]
    perso["db_name"]=data["stuff"]["name"]
    perso["PA"]=7
    if perso["Lvl"]<100:
        perso["PA"]-=1
    perso["PM"]=3
    perso["Invocation"]=1
    perso["Vitalité"]=50+5*perso["Lvl"]

    for elt in perso_stats:
        perso[TRAD_DB_STATS[elt]]+=perso_stats[elt]
    
    for elt in fmglobal:
        try:
            perso[TRAD_DB_STATS[elt]]+=fmglobal[elt]
        except:
            pass #au cas où y'a un effet rajouté que je reconnais pas, genre 10% dommages distance, go ignorer
    for item in fmitems:
        for elt in fmitems[item]:
            try:
                perso[TRAD_DB_STATS[elt]]+=fmitems[item][elt]
            except:
                pass #au cas où y'a un effet rajouté que je reconnais pas, genre 10% dommages distance, go ignorer
    for item in items:
        for stat in item["effects"]:
            if stat["type"]=='E':
                try:
                    if stat["min"]>=0:
                        perso[TRAD_DB_STATS[stat["name"]]]+=stat["max"]
                    else:
                        perso[TRAD_DB_STATS[stat["name"]]]+=stat["min"]
                except : # cas genre dommages pièges (pi) ou puissance pièges (pip) j'ignore
                    pass
    for pano in panos:
        for stat in pano["effects"]:
            if stat["type"]=='E':
                try:
                    perso[TRAD_DB_STATS[stat["name"]]]+=stat["value"]
                except:
                    pass #on ignore les stats inconnues
    #bonus dérivés de stats
    # perso["Soin"]+=max(0,perso["Intelligence"]/10//1)
    if jeu=="Dofus Touch":
        perso["Fuite"]+=int(max(0,perso["Chance"]/10//1))
        perso["Tacle"]+=int(max(0,perso["Agilité"]/10//1))
    else :
        perso["Fuite"]+=int(max(0,perso["Agilité"]/10//1))
        perso["Tacle"]+=int(max(0,perso["Agilité"]/10//1))
    perso["Esq. PA"]+=int(max(0,perso["Sagesse"]/10//1))
    perso["Esq. PM"]+=int(max(0,perso["Sagesse"]/10//1))
    perso["Ret. PA"]+=int(max(0,perso["Sagesse"]/10//1))
    perso["Ret. PM"]+=int(max(0,perso["Sagesse"]/10//1))
    perso["Initiative"]+=int(max(0,perso["Intelligence"]))+int(max(0,perso["Chance"]))+int(max(0,perso["Agilité"]))+int(max(0,perso["Force"]))

    return perso


def get_stuff_base_info(id,driver,jeu="Dofus Touch"):
    resp=get_stats(id,driver,jeu)
    ans={
        "DB_surl": resp["DB_surl"],
        "PA": resp["PA"],
        "PM": resp["PM"],
        "PO": resp["PO"],
        "Invo": resp["Invocation"],
        "Lvl" : resp["Lvl"]
        }
    return ans

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
print(get_stuff_base_info("20861615",driver,jeu="Dofus 3"))
print(get_stuff_base_info("1912504",driver,jeu="Dofus Retro"))
print(get_stuff_base_info("2110438",driver,jeu="Dofus Retro"))
print(get_stuff_base_info("3033375",driver,jeu="Dofus Touch"))
# Out:
# https://www.dofusbook.net/api/stuffs/dofus/public/20861615
# {'DB_surl': '1PX3f', 'PA': 12, 'PM': 6, 'PO': -2, 'Invo': 3, 'Lvl': 200}
# https://retro.dofusbook.net/api/stuffs/retro/public/1912504
# {'DB_surl': '81Wq', 'PA': 10, 'PM': 4, 'PO': 0, 'Invo': 3, 'Lvl': 100}
# https://retro.dofusbook.net/api/stuffs/retro/public/2110438
# {'DB_surl': '8r1K', 'PA': 8, 'PM': 6, 'PO': 3, 'Invo': 1, 'Lvl': 134}
# https://touch.dofusbook.net/api/stuffs/touch/public/3033375
# {'DB_surl': 'Cj7P', 'PA': 11, 'PM': 6, 'PO': 5, 'Invo': 1, 'Lvl': 200}

# %%
print(get_stats("20861615",driver,jeu="Dofus 3"))
print(get_stats("1912504",driver,jeu="Dofus Retro"))
print(get_stats("2110438",driver,jeu="Dofus Retro"))
print(get_stats("3033375",driver,jeu="Dofus Touch"))
# Out:
# https://www.dofusbook.net/api/stuffs/dofus/public/20861615
# {'Lvl': 200, 'PA': 12, 'PM': 6, 'PO': -2, 'Initiative': 2740, 'Critique': 76, 'Invocation': 3, 'Soin': -17, 'Vitalité': 4595, 'Sagesse': 435, 'Force': 260, 'Intelligence': 1221, 'Chance': 260, 'Agilité': 100, 'Puissance': 90, 'Fuite': -1.0, 'Esq. PA': 43.0, 'Esq. PM': 37.0, 'Pods': 0, 'Tacle': 124.0, 'Ret. PA': 43.0, 'Ret. PM': 88.0, 'Do Critique': 110, '% Ré Air': 43, '% Ré Feu': 35, 'Do Eau': 31, 'Do Terre': 46, 'Do Neutre': 31, '% Ré Terre': 34, 'Prospection': 40, 'Do Feu': 98, 'Do Air': 0, 'Do Poussée': 75, 'Ré Neutre': 0, '% Ré Neutre': 36, 'Ré Terre': 0, 'Ré Feu': 35, 'Ré Eau': 0, '% Ré Eau': 31, 'Ré Air': 0, 'Ré Critique': 0, 'Ré Poussée': 0, 'Do': 0, 'DB_surl': '1PX3f', 'db_name': 'Feu - Crit'}
# https://retro.dofusbook.net/api/stuffs/retro/public/1912504
# ...

# %%
try:
    resp = json.loads(pre_text)["rows"]
    # print(resp)
except Exception as e:
    print("Erreur :",e)

taille=len(resp)
# Out:
# Erreur : name 'pre_text' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 7
#       4 except Exception as e:
#       5     print("Erreur :",e)
# ----> 7 taille=len(resp)
#
# NameError: name 'resp' is not defined

# %%
import requests

url = "https://touch.dofusbook.net/api/stuffs/touch/t/public/3158931"
headers = {"x-dbk": "sses-5z5d5qzd5-qzd5155ds-q4z45z5d"}
response = requests.get(url,headers=headers)
# print(response.json())
print(response.text)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <title>Attention Required! | Cloudflare</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
# <style>body{margin:0;padding:0}</style>
#
#
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
# ...

# %%
from dotenv import load_dotenv
import os

load_dotenv()
HEADER_NAME = os.getenv('HEADER_NAME')
HEADER_VALUE = os.getenv('HEADER_VALUE')

# %%
url="https://touch.dofusbook.net/api/stuffs/touch/public/3158931"
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
# Intercepteur : ajoute le header uniquement pour les URLs de l’API
def interceptor_hd_id_DB(request):
    if request.url.startswith("https://touch.dofusbook.net/api/"):
        request.headers[HEADER_NAME] = HEADER_VALUE

driver.request_interceptor = interceptor_hd_id_DB
driver.get(url)
try:
    pre_text = driver.find_element("tag name", "pre").text
    data = json.loads(pre_text)
    print(data)
except Exception as e:
    print(e)
    print(driver.page_source)
# Out:
# {'source': 'database', 'stuff': {'avatar': '70_1', 'slug': '3158931-mazin-pnose-soin', 'elapsed_time': '1 h', 'short_url': 'DFmV', 'allowed_classes': [7, 5, 13, 1, 15], 'tags': ['feu', 'eau', 'so'], 'id': 3158931, 'user_id': 996244, 'character_class': 7, 'character_gender': 0, 'folder_id': None, 'visible': True, 'name': 'mazin pnose soin', 'character_level': 200, 'description': None, 'markdown': None, 'updated_at': '2025-10-25T21:07:28.000Z', 'created_at': '2025-10-25T21:05:36.000Z', 'stuffCarac': {'scroll_vi': 100, 'scroll_sa': 100, 'scroll_fo': 100, 'scroll_in': 100, 'scroll_ch': 100, 'scroll_ag': 100, 'base_vi': 595, 'base_sa': 0, 'base_fo': 0, 'base_in': 150, 'base_ch': 150, 'base_ag': 0}, 'stuffFm': {'fm': {'pa': 1, 'pm': 1, 'po': 1}, 'caracs': 'pa,pm,po', 'values': '1,1,1', 'weapon': 'de-85', 'steal': None}, 'stuffFmItem': {'a1': {}, 'a2': {}, 'am': {}, 'ar': {}, 'bo': {}, 'br': {}, 'ca': {}, 'ce': {}, 'ch': {}, 'd1': {}, 'd2': {}, 'd3': {}, 'd4': {}, 'd5': {}, 'd6': {}, 'fa': 
# ...
